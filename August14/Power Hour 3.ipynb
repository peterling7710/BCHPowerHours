# %% [markdown]
# ## Power Hour #3
#
# This power hour is designed to practice pandas plotting and ML with Python

# %%
# Step 1: Let's get some data
from sklearn.datasets import load_boston
from IPython.display import display
import pandas as pd
import seaborn as sns
import numpy as np

# %%
dataset = load_boston()
a = load_boston(return_X_y=False)

# %%
display(dataset)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
features = dataset.feature_names
data = dataset.data
Y = dataset.target
all_data = np.concatenate([data, Y[:, np.newaxis]], axis=1)

# %%
print(data.shape, Y[:, np.newaxis].shape)
# Out:
# (506, 13) (506, 1)

# %%
print(len(data), len(Y))
# Out:
# 506 506

# %%
a
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
dfa = pd.DataFrame(data=all_data, columns = np.append(features, "Y"))

# %%
features
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
df = pd.DataFrame(data = data, columns = features)

# %%
# Step 2: Data exploration
dfa.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT     Y
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.ndim
# Out:
# 2

# %%
df.corr().ndim
# Out:
# 2

# %%
sns.heatmap(dfa.corr())

# %%
a = dfa.corr()
a[a['Y'] > 0]['Y']
# Out:
# ZN      0.360445
# CHAS    0.175260
# RM      0.695360
# DIS     0.249929
# B       0.333461
# Y       1.000000
# Name: Y, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(data, Y, test_size=0.1, random_state=7)

# %%
# Step 3: Fit a model to our data

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
t = DecisionTreeRegressor(max_depth=4)

# %%
t.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=4, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
from sklearn.metrics import r2_score

Y_pred = t.predict(X_test)

print(r2_score(Y_test, Y_pred))
# Out:
# 0.7835537332288495

# %%
# Step 4: Basic model validation

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
#Visualize our tree
#Value is the number of samples per split
#The left branch is True and the right branch is False
plt.figure(figsize=(25,10))
a = plot_tree(t, 
              feature_names=features, 
              filled=True, 
              rounded=True, 
              fontsize=14)

# %%
np.c_[xx.ravel(), yy.ravel()].shape
# Out:
# (8, 2)
